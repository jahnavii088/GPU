# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavii088/GPU/blob/main/GPU2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Jul 30 09:31:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %%writefile hello.cu
# #include<stdio.h>
#
# __global__ void helloGPU(){
#   printf("Hello World from GPU!\n");
# }
#
# int main(){
#   printf("Hello World from CPU\n");
#
#   helloGPU<<<1,1>>>();
#
#   cudaDeviceSynchronize();
#
#   return 0;
# }
# Out:
# Writing hello.cu

# %%
# !nvcc hello.cu -o hello
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
! ./hello
# Out:
# Hello World from CPU
# Hello World from GPU!
